# %%
import gymnasium as gym
import numpy as np
import pandas as pd

# %%
def obs_to_text(obs):
    starter = "Observation from last step: "
    x_coordinate = f"X coordinate: {obs[0]:2f}"
    y_coordinate = f"Y coordinate: {obs[1]:.2f}"
    x_velocity = f"X velocity: {obs[2]:.2f}"
    y_velocity = f"Y velocity: {obs[3]:.2f}"
    lander_angle = f"Angle of the lander: {obs[4]:.2f}"
    angular_velocity = obs[5] * 2.5
    angular_velocity = f"Angular velocity of lander: {angular_velocity}"
    leg_1_contact_flag = f"Leg 1 contact with ground flag: {obs[6]}"
    leg_2_contact_flag = f"Leg 2 contact with ground flag: {obs[7]}"
     
    return "\n".join([starter, x_coordinate, y_coordinate, x_velocity, y_velocity, lander_angle, angular_velocity, leg_1_contact_flag, leg_2_contact_flag])

def reward_to_text(reward):
    return f"The reward from the last step was: {reward:.2f}"

def text_to_action(text):
    """
        Given an output by the LLM in the form:
        0 - "do nothing"
        1 - "fire left orientation engine"
        2 - "fire main engine"
        3 - "fire right orientation engine"
        This function will return the corresponding action values for the environment 
    """
    action = text[0]
    return int(action)

# %%
primer = """
Imagine you are an expert at controlling a lunar lander, and you have been given the task of controlling a lunar landing rover in a reinforcement learning environment. The challenge is to land the lander between the two yellow flags on the surface that mark the landing zone. The lander has a square body and two legs. This environment is a classic rocket trajectory optimization problem. According to Pontryagin's maximum principle, it is optimal to fire the engine at full throttle or turn it off. This is the reason why this environment has discrete actions: engine on or off.

You will be given scenarios in the form of observations from the environment and the reward based on the last action and the Current Total Score. Your goal is to provide one of the following actions based on the previous observation:

'0 - Do nothing, 1 - fire left orientation engine, 2 - fire main engine, 3 - fire right orientation engine'

Your goal is to maximize the reward and land the lander on the landing pad. Only provide the action and no additional explanation. The episode finishes if:

- the lander crashes (the lander body gets in contact with the moon);

- the lander gets outside of the viewport (x coordinate is greater than 1);

Rewards:
After every step a reward is granted. The total reward of an episode is the sum of the rewards for all the steps within that episode.

For each step, the reward:

- is increased/decreased the closer/further the lander is to the landing pad.

- is increased/decreased the slower/faster the lander is moving.

- is decreased the more the lander is tilted (angle not horizontal).

- is increased by 10 points for each leg that is in contact with the ground.

- is decreased by 0.03 points each frame a side engine is firing.

- is decreased by 0.3 points each frame the main engine is firing.

The episode receive an additional reward of -100 or +100 points for crashing or landing safely respectively. An episode is considered a solution if it scores at least 200 points.

Observation:
The observation state is an 8-dimensional vector: the coordinates of the lander in x & y, its linear velocities in x & y, its angle, its angular velocity, and two booleans that represent whether each leg is in contact with the ground or not.

Example Observation:
'Observation from last step: \nX coordinate: -0.02\nY coordinate: -0.03\nX velocity: -0.03\nY velocity: -0.01\nAngle of the lander: 0.48\nAngular velocity of lander: 0.48\nLeg 1 contact with ground flag: -0\nLeg 1 contact with ground flag: 1'
'The reward from the last step was: -0.25'
Score: -0.25

Action: 3 - fire right orientation engine
"""

obs_skeleton = """
_
{obs_step}
{reward_step}
score: {score_step}

Action: 
"""

obs_skeleton_reset = """
Now, given the following observation, rewards and score give me the next action for the following scenario:
_
{obs_step}
reward: None as it is the first step
score: 0

Action:
"""

# %% [markdown]
# ## Training Testing

# %%
# !pip3 install openai
# Out:
# Requirement already satisfied: openai in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (1.12.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from openai) (3.6.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from openai) (1.10.4)
# Requirement already satisfied: sniffio in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from openai) (4.66.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from openai) (4.9.0)
# Requirement already satisfied: idna>=2.8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (1.0.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip3 install --upgrade pip

# %%
import openai
import os
import time

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
STEPS = 500
OBS_TEXT_LENGTH = 800
PRIMER_STARTER_LENGTH = 2000
NUMBER_OF_OBS_MEMORY = 3 
save_dir = "runs/lunar_lander/"
NUMBER_ACTIONS = 5

# %%
# Init env
env = gym.make("LunarLander-v3", continuous=False, render_mode="human")
obs, info = env.reset()

client = openai.OpenAI(api_key=OPENAI_API_KEY)
def get_action(primer, client):
    print("Getting action from LLM")
    response = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "user", "content": primer}
    ],
    response_format={
      "type": "text"
    },
    temperature=0.2,
    max_tokens=200,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
    )

    action_text = response.choices[0].message.content
    print(action_text)
    return action_text

def save_obs(obs, reward, score, step, store={}):
    obs_text = obs_to_text(obs)
    reward_text = reward_to_text(reward)
    score_text = f"Score: {score}"
    obs_skeleton_filled = obs_skeleton.format(obs_step=obs_text, reward_step=reward_text, score_step=score_text)
    inner = {
        "obs": obs,
        "obs_text": obs_text,
        "reward": reward,
        "reward_text": reward_text,
        "score": score,
        "skeleton": obs_skeleton_filled
    }
    store[step] = inner

# %%
score, reward, done, store = 0, 0, False, {}
obs, _ = env.reset()

# Make first primer
obs_text = obs_to_text(obs)
primer += obs_skeleton_reset.format(obs_step=obs_text)

for i in range(STEPS):
    # sleep to not exceed the rate limit
    time.sleep(5)

    # Get action from gpt
    action_text = get_action(primer, client)
    action = text_to_action(action_text)

    save_obs(obs, reward, score, i, store)

    # Perform action
    obs, reward, done, _, _ = env.step(action)
    if done:
        print("The lander has crashed or moved outside the viewport (X coordinate > 1). The total score was: ", score)
        break

    # Update score
    score += reward

    # Generate new primer
    obs_text = obs_to_text(obs)
    reward_text = reward_to_text(reward)
    obs_step = obs_skeleton.format(obs_step=obs_text, reward_step=reward_text, score_step=score)
    primer += action_text + "\n" + obs_step
    
# Check length of primer
    if len(primer) > PRIMER_STARTER_LENGTH + OBS_TEXT_LENGTH*NUMBER_OF_OBS_MEMORY or len(primer) > 4096:
        # split at "_" get the primer front and the continuation
        primer_splits = primer.split("_")
        primer = primer_splits[0] + "_" + "".join(primer_splits[2:]) # Remove the first observation and reward from memory

# Save the store as df
df = pd.DataFrame(store).T
# Out:
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# Getting action from LLM
# 2 - fire main engine
# The lander has crashed or moved outside the viewport (X coordinate > 1). The total score was:  -551.4150402068778

# %%
env.close()

# %%
# save df
df.to_csv(save_dir + "run_1.csv")

# %% [markdown]
# ## Increase number of actions per step

# %%
def rewards_to_text(rewards):
    # Gets a list of rewards and returns a string with the rewards in the form "[reward1, reward2, reward3]"
    return "[" + ", ".join([str(reward) for reward in rewards]) + "]"

# %%
primer = """
Imagine you are an expert at controlling a lunar lander, and you have been given the task of controlling a lunar landing rover in a reinforcement learning environment. The challenge is to land the lander between the two yellow flags on the surface that mark the landing zone. The lander has a square body and two legs. This environment is a classic rocket trajectory optimization problem. According to Pontryagin's maximum principle, it is optimal to fire the engine at full throttle or turn it off. This is the reason why this environment has discrete actions: engine on or off.

You will be given scenarios in the form of observations from the environment and the reward based on the last action and the Current Total Score. Your goal is to provide 5 of the following actions based on the previous observation:

'0 - Do nothing, 1 - fire left orientation engine, 2 - fire main engine, 3 - fire right orientation engine'

Your goal is to maximize the reward and land the lander on the landing pad. Only provide the action and no additional explanation. The episode finishes if:

- the lander crashes (the lander body gets in contact with the moon);

- the lander gets outside of the viewport (x coordinate is greater than 1);

Rewards:
After every step a reward is granted. The total reward of an episode is the sum of the rewards for all the steps within that episode.

For each step, the reward:

- is increased/decreased the closer/further the lander is to the landing pad.

- is increased/decreased the slower/faster the lander is moving.

- is decreased the more the lander is tilted (angle not horizontal).

- is increased by 10 points for each leg that is in contact with the ground.

- is decreased by 0.03 points each frame a side engine is firing.

- is decreased by 0.3 points each frame the main engine is firing.

The episode receive an additional reward of -100 or +100 points for crashing or landing safely respectively. An episode is considered a solution if it scores at least 200 points.

Observation:
The observation state is an 8-dimensional vector: the coordinates of the lander in x & y, its linear velocities in x & y, its angle, its angular velocity, and two booleans that represent whether each leg is in contact with the ground or not.

Example Observation:
'Observation from last step: \nX coordinate: -0.02\nY coordinate: -0.03\nX velocity: -0.03\nY velocity: -0.01\nAngle of the lander: 0.48\nAngular velocity of lander: 0.48\nLeg 1 contact with ground flag: -0\nLeg 1 contact with ground flag: 1'
'The reward from the last step was: -0.25'
Score: -0.25

Example Actions:

3 - fire right orientation engine
2 - fire main engine
0 - Do nothing
1 - fire left orientation engine
"""

obs_skeleton = """
_
{obs_step}
rewards: {reward_step}
score: {score_step}

Actions 
"""

obs_skeleton_reset = """
Now, given the following observation, rewards and score give me the optimal best {no_actions} action for the following scenario:
_
{obs_step}
reward: None as it is the first step
score: 0

Action:
"""

# %%
STEPS = 100
OBS_TEXT_LENGTH = 1200
PRIMER_STARTER_LENGTH = 2400
NUMBER_OF_OBS_MEMORY = 4
save_dir = "runs/lunar_lander/"
NUMBER_ACTIONS = 5

# %%
#Init env
env = gym.make("LunarLander-v3", continuous=False, render_mode="human")
obs, info = env.reset()

client = openai.OpenAI(api_key=OPENAI_API_KEY)
def get_action(primer, client):
    print("Getting action from LLM")
    response = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "user", "content": primer}
    ],
    response_format={
      "type": "text"
    },
    temperature=0.2,
    max_tokens=200,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
    )

    action_text = response.choices[0].message.content
    return action_text

def save_obs(obs, reward, score, step, actions_text, actions, store={}):
    obs_text = obs_to_text(obs)
    reward_text = reward_to_text(reward)
    score_text = f"Score: {score}"
    obs_skeleton_filled = obs_skeleton.format(obs_step=obs_text, reward_step=reward_text, score_step=score_text)
    inner = {
        "obs": obs,
        "obs_text": obs_text,
        "reward": reward,
        "reward_text": reward_text,
        "score": score,
        "skeleton": obs_skeleton_filled,
        "actions_text": actions_text,
        "actions": actions
    }
    store[step] = inner

# %%
score, rewards, done, store = 0, [], False, {}
action_text_store, action_store = [], []
obs, _ = env.reset()

# Make first primer
obs_text = obs_to_text(obs)
primer += obs_skeleton_reset.format(obs_step=obs_text, no_actions=NUMBER_ACTIONS)

for i in range(STEPS):
    # sleep to not exceed the rate limit
    time.sleep(20)

    # Get action from gpt
    response = get_action(primer, client)
    action_texts = response.split("\n")
    for action_text in action_texts:
        # Get each of the actions given by the LLM
        action = text_to_action(action_text)
        print(action)
        # perform action
        obs, reward, done, _, _ = env.step(action)

        # Update score
        score += reward
        
        # save the reward
        rewards.append(reward)
        # save the action
        action_text_store.append(action_text)
        action_store.append(action)

        # Add the action to the primer
        primer += action_text + "\n"

        if done:
            print("The lander has crashed or moved outside the viewport (X coordinate > 1). The total score was: ", score)
            break

    save_obs(obs, reward, score, i, action_text_store, action_store, store)

    # Generate new primer
    obs_text = obs_to_text(obs)
    reward_text = rewards_to_text(rewards)
    obs_step = obs_skeleton.format(obs_step=obs_text, reward_step=reward_text, score_step=score)
    primer += obs_step # actions are already added

    # reset rewards
    rewards = []
    action_text_store = []
    action_store = []

    # Check length of primer
    if len(primer) > PRIMER_STARTER_LENGTH + OBS_TEXT_LENGTH*NUMBER_OF_OBS_MEMORY:
        # split at "_" get the primer front and the continuation
        primer_splits = primer.split("_")
        primer = primer_splits[0] + "_" + "".join(primer_splits[2:]) # Remove the first observation and reward from memory

# Save the store as df
df = pd.DataFrame(store).T
# Out:
# Getting action from LLM
# 2
# 2
# 2
# 0
# 0
# Getting action from LLM
# 2
# 2
# 2
# 0
# 0
# Getting action from LLM
# 2
# 2
# 2
# 0
# 0
# Getting action from LLM
# 2
# 2
# 1
# 0
# 0
# Getting action from LLM
# 2
# 2
# 1
# 0
# 0
# Getting action from LLM
# 2
# 2
# 1
# 0
# 0
# Getting action from LLM
# 2
# 2
# 1
# 0
# 0
# Getting action from LLM
# 2
# 2
# 1
# 0
# 0
# Getting action from LLM
# 2
# 2
# 1
# 0
# 0
# Getting action from LLM
# 2
# 1
# 2
# 1
# 2
# Getting action from LLM
# 2
# 1
# 2
# 1
# 2
# Getting action from LLM
# 2
# 1
# 2
# 1
# 2
# Getting action from LLM
# 2
# 1
# 2
# 1
# 2
# Getting action from LLM
# 2
# 1
# 2
# 1
# 2
# Getting action from LLM
# 2
# 1
# 2
# 1
# 2
# Getting action from LLM
# 2
# 1
# 2
# 1
# 2
# Getting action from LLM
# 2
# 1
# 2
# 1
# 2
# Getting action from LLM
# 2
# The lander has crashed or moved outside the viewport (X coordinate > 1). The total score was:  -500.79239674224465
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [69], line 11
#       7 primer += obs_skeleton_reset.format(obs_step=obs_text, no_actions=NUMBER_ACTIONS)
#       9 for i in range(STEPS):
#      10     # sleep to not exceed the rate limit
# ---> 11     time.sleep(20)
#      13     # Get action from gpt
#      14     response = get_action(primer, client)
#
# KeyboardInterrupt:

# %%
env.close()

# %%
df.to_csv(save_dir + "run_2.csv")

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
df
# Out:
#                                                                                           obs  \
# 0    [-0.0036893846, 1.4124846, -0.37371176, 0.069520235, 0.0042818994, 0.08465126, 0.0, 0.0]
# 1    [-0.0073950766, 1.4142457, -0.37472457, 0.07826131, 0.0083990665, 0.082351506, 0.0, 0.0]
# 2        [-0.011085033, 1.416822, -0.37326404, 0.11446548, 0.012627807, 0.08458259, 0.0, 0.0]
# 3        [-0.014760876, 1.420248, -0.37199038, 0.15222766, 0.016981823, 0.08708827, 0.0, 0.0]
nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0
# 103    Observation from last step: \nX coordinate: -0.924566\nY coordinate: 3.91\nX velocity: -1.52\nY velocity: 2.05\nAngle of the lander: 0.14\nAngular velocity of lander: 0.004758636350743473\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0
# 104    Observation from last step: \nX coordinate: -0.939874\nY coordinate: 3.96\nX velocity: -1.53\nY velocity: 2.05\nAngle of the lander: 0.14\nAngular velocity of lander: -0.01442602719180286\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0
# 105   Observation from last step: \nX coordinate: -0.955286\nY coordinate: 4.00\nX velocity: -1.54\nY velocity: 2.07\nAngle of the lander: 0.14\nAngular velocity of lander: -0.016013936838135123\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0
# 106    Observation from last step: \nX coordinate: -0.970986\nY coordinate: 4.05\nX velocity: -1.57\nY velocity: 2.10\nAngle of the lander: 0.14\nAngular velocity of lander: -0.05561973433941603\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0
# 107    Observation from last step: \nX coordinate: -0.986795\nY coordinate: 4.10\nX velocity: -1.58\nY velocity: 2.11\nAngle of the lander: 0.14\nAngular velocity of lander: -0.06298148073256016\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0
#
#        reward                               reward_text       score  \
# 0           0   The reward from the last step was: 0.00           0
# 1   -1.157953  The reward from the last step was: -1.16   -1.157953
# 2   -1.743997  The reward from the last step was: -1.74    -2.90195
# 3   -2.232561  The reward from the last step was: -2.23   -5.134511
# 4    -0.74208  The reward from the last step was: -0.74   -5.876591
# 5   -1.851221  The reward from the last step was: -1.85   -7.727812
# 6   -1.331493  The reward from the last step was: -1.33   -9.059305
# 7   -3.312946  The reward from the last step was: -3.31  -12.372251
# 8   -2.114003  The reward from the last step was: -2.11  -14.486254
# 9   -3.591118  The reward from the last step was: -3.59  -18.077373
# 10  -2.288628  The reward from the last step was: -2.29  -20.366001
# 11  -4.580274  The reward from the last step was: -4.58  -24.946276
# 12  -3.650234  The reward from the last step was: -3.65  -28.596509
# 13  -5.128593  The reward from the last step was: -5.13  -33.725103
# 14  -2.086578  The reward from the last step was: -2.09  -35.811681
# 15  -3.357651  The reward from the last step was: -3.36  -39.169331
# 16  -4.254788  The reward from the last step was: -4.25  -43.424119
# 17  -2.156038  The reward from the last step was: -2.16  -45.580157
# 18  -3.040701  The reward from the last step was: -3.04  -48.620859
# 19  -4.150932  The reward from the last step was: -4.15  -52.771791
# 20  -5.573859  The reward from the last step was: -5.57   -58.34565
# 21  -4.632354  The reward from the last step was: -4.63  -62.978004
# 22   -4.07385  The reward from the last step was: -4.07  -67.051854
# 23  -2.819579  The reward from the last step was: -2.82  -69.871433
# 24  -4.262468  The reward from the last step was: -4.26  -74.133901
# 25   -4.96636  The reward from the last step was: -4.97  -79.100261
# 26  -2.085215  The reward from the last step was: -2.09  -81.185476
# 27  -3.099935  The reward from the last step was: -3.10  -84.285411
# 28  -3.777235  The reward from the last step was: -3.78  -88.062647
# 29  -3.685206  The reward from the last step was: -3.69  -91.747852
# 30  -5.422225  The reward from the last step was: -5.42  -97.170077
# 31  -5.391486  The reward from the last step was: -5.39 -102.561563
# 32  -5.339931  The reward from the last step was: -5.34 -107.901494
# 33  -3.423236  The reward from the last step was: -3.42  -111.32473
# 34  -2.981849  The reward from the last step was: -2.98 -114.306579
# 35  -5.411479  The reward from the last step was: -5.41 -119.718058
# 36  -5.907503  The reward from the last step was: -5.91 -125.625561
# 37   -7.28438  The reward from the last step was: -7.28 -132.909941
# 38  -6.347091  The reward from the last step was: -6.35 -139.257032
# 39  -5.915559  The reward from the last step was: -5.92 -145.172591
# 40  -4.761367  The reward from the last step was: -4.76 -149.933957
# 41  -3.472404  The reward from the last step was: -3.47 -153.406362
# 42   -5.10266  The reward from the last step was: -5.10 -158.509021
# 43  -3.864693  The reward from the last step was: -3.86 -162.373715
# 44  -3.125114  The reward from the last step was: -3.13 -165.498829
# 45  -3.381872  The reward from the last step was: -3.38 -168.880701
# 46  -6.676692  The reward from the last step was: -6.68 -175.557392
# 47  -4.737857  The reward from the last step was: -4.74  -180.29525
# 48  -6.316883  The reward from the last step was: -6.32 -186.612132
# 49  -5.314709  The reward from the last step was: -5.31 -191.926842
# 50  -6.602648  The reward from the last step was: -6.60  -198.52949
# 51  -3.643105  The reward from the last step was: -3.64 -202.172595
# 52  -6.582158  The reward from the last step was: -6.58 -208.754754
# 53  -3.967709  The reward from the last step was: -3.97 -212.722463
# 54  -5.001958  The reward from the last step was: -5.00 -217.724421
# 55    -3.2948  The reward from the last step was: -3.29 -221.019221
# 56   -2.96929  The reward from the last step was: -2.97 -223.988511
# 57  -4.068281  The reward from the last step was: -4.07 -228.056791
# 58  -6.025195  The reward from the last step was: -6.03 -234.081987
# 59  -6.112094  The reward from the last step was: -6.11 -240.194081
# 60  -7.433893  The reward from the last step was: -7.43 -247.627974
# 61  -7.319738  The reward from the last step was: -7.32 -254.947712
# 62  -3.650339  The reward from the last step was: -3.65 -258.598051
# 63  -7.073182  The reward from the last step was: -7.07 -265.671233
# 64   -5.26085  The reward from the last step was: -5.26 -270.932082
# 65   -6.79742  The reward from the last step was: -6.80 -277.729503
# 66  -7.266754  The reward from the last step was: -7.27 -284.996257
# 67  -7.782062  The reward from the last step was: -7.78 -292.778319
# 68   -4.99066  The reward from the last step was: -4.99 -297.768979
# 69  -4.991425  The reward from the last step was: -4.99 -302.760405
# 70  -5.694024  The reward from the last step was: -5.69 -308.454428
# 71   -5.10894  The reward from the last step was: -5.11 -313.563369
# 72  -5.273633  The reward from the last step was: -5.27 -318.837002
# 73  -8.288199  The reward from the last step was: -8.29 -327.125201
# 74  -5.949939  The reward from the last step was: -5.95  -333.07514
# 75  -6.157277  The reward from the last step was: -6.16 -339.232417
# 76  -7.021413  The reward from the last step was: -7.02  -346.25383
# 77  -6.876564  The reward from the last step was: -6.88 -353.130394
# 78  -3.682332  The reward from the last step was: -3.68 -356.812726
# 79  -6.719118  The reward from the last step was: -6.72 -363.531844
# 80  -8.243457  The reward from the last step was: -8.24 -371.775301
# 81  -7.666844  The reward from the last step was: -7.67 -379.442145
# 82  -7.027391  The reward from the last step was: -7.03 -386.469536
# 83  -8.955241  The reward from the last step was: -8.96 -395.424778
# 84  -5.033719  The reward from the last step was: -5.03 -400.458497
# 85  -5.715071  The reward from the last step was: -5.72 -406.173568
# 86  -8.296429  The reward from the last step was: -8.30 -414.469998
# 87  -4.931076  The reward from the last step was: -4.93 -419.401074
# 88  -5.054525  The reward from the last step was: -5.05 -424.455599
# 89  -6.066449  The reward from the last step was: -6.07 -430.522048
# 90  -4.601895  The reward from the last step was: -4.60 -435.123944
# 91  -5.670541  The reward from the last step was: -5.67 -440.794485
# 92  -8.669049  The reward from the last step was: -8.67 -449.463533
# 93  -5.706192  The reward from the last step was: -5.71 -455.169725
# 94  -5.381848  The reward from the last step was: -5.38 -460.551572
# 95  -7.858569  The reward from the last step was: -7.86 -468.410141
# 96  -6.311871  The reward from the last step was: -6.31 -474.722012
# 97  -5.432012  The reward from the last step was: -5.43 -480.154025
# 98  -7.712934  The reward from the last step was: -7.71 -487.866958
# 99    -6.1275  The reward from the last step was: -6.13 -493.994458
# 100 -6.545116  The reward from the last step was: -6.55 -500.539574
# 101 -9.180354  The reward from the last step was: -9.18 -509.719928
# 102 -4.477587  The reward from the last step was: -4.48 -514.197515
# 103 -7.554558  The reward from the last step was: -7.55 -521.752073
# 104 -6.654524  The reward from the last step was: -6.65 -528.406597
# 105 -7.294755  The reward from the last step was: -7.29 -535.701352
# 106 -9.063648  The reward from the last step was: -9.06    -544.765
# 107  -6.65004  The reward from the last step was: -6.65  -551.41504
#
# ...
# 65    \n_\nObservation from last step: \nX coordinate: -0.409295\nY coordinate: 2.46\nX velocity: -1.10\nY velocity: 1.28\nAngle of the lander: 0.20\nAngular velocity of lander: -0.07031247019767761\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -6.80\nscore: Score: -277.72950272030744\n\nAction: \n
# 66    \n_\nObservation from last step: \nX coordinate: -0.420562\nY coordinate: 2.49\nX velocity: -1.12\nY velocity: 1.31\nAngle of the lander: 0.20\nAngular velocity of lander: -0.09187429212033749\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -7.27\nscore: Score: -284.99625678917437\n\nAction: \n
# 67     \n_\nObservation from last step: \nX coordinate: -0.432064\nY coordinate: 2.52\nX velocity: -1.15\nY velocity: 1.35\nAngle of the lander: 0.20\nAngular velocity of lander: -0.10010615922510624\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -7.78\nscore: Score: -292.7783190094923\n\nAction: \n
# 68     \n_\nObservation from last step: \nX coordinate: -0.443730\nY coordinate: 2.55\nX velocity: -1.16\nY velocity: 1.36\nAngle of the lander: 0.20\nAngular velocity of lander: -0.11341503821313381\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -4.99\nscore: Score: -297.7689792383964\n\nAction: \n
# 69    \n_\nObservation from last step: \nX coordinate: -0.455410\nY coordinate: 2.58\nX velocity: -1.17\nY velocity: 1.38\nAngle of the lander: 0.19\nAngular velocity of lander: -0.08540634997189045\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -4.99\nscore: Score: -302.76040458950666\n\nAction: \n
# 70     \n_\nObservation from last step: \nX coordinate: -0.467301\nY coordinate: 2.61\nX velocity: -1.19\nY velocity: 1.39\nAngle of the lander: 0.19\nAngular velocity of lander: -0.10699274018406868\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -5.69\nscore: Score: -308.4544283523048\n\nAction: \n
# 71      \n_\nObservation from last step: \nX coordinate: -0.479417\nY coordinate: 2.64\nX velocity: -1.21\nY velocity: 1.40\nAngle of the lander: 0.19\nAngular velocity of lander: -0.1373414508998394\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -5.11\nscore: Score: -313.5633686056923\n\nAction: \n
# 72      \n_\nObservation from last step: \nX coordinate: -0.491563\nY coordinate: 2.67\nX velocity: -1.21\nY velocity: 1.42\nAngle of the lander: 0.19\nAngular velocity of lander: -0.113056730479002\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -5.27\nscore: Score: -318.83700195153466\n\nAction: \n
# 73    \n_\nObservation from last step: \nX coordinate: -0.503984\nY coordinate: 2.70\nX velocity: -1.24\nY velocity: 1.46\nAngle of the lander: 0.18\nAngular velocity of lander: -0.13284163549542427\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -8.29\nscore: Score: -327.12520068952716\n\nAction: \n
# 74      \n_\nObservation from last step: \nX coordinate: -0.516676\nY coordinate: 2.74\nX velocity: -1.27\nY velocity: 1.47\nAngle of the lander: 0.18\nAngular velocity of lander: -0.1708303950726986\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -5.95\nscore: Score: -333.0751398255815\n\nAction: \n
# 75     \n_\nObservation from last step: \nX coordinate: -0.529481\nY coordinate: 2.77\nX velocity: -1.28\nY velocity: 1.49\nAngle of the lander: 0.18\nAngular velocity of lander: -0.16445733606815338\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -6.16\nscore: Score: -339.2324171113029\n\nAction: \n
# 76    \n_\nObservation from last step: \nX coordinate: -0.542338\nY coordinate: 2.81\nX velocity: -1.28\nY velocity: 1.53\nAngle of the lander: 0.17\nAngular velocity of lander: -0.13615308329463005\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -7.02\nscore: Score: -346.25383020041505\n\nAction: \n
# 77    \n_\nObservation from last step: \nX coordinate: -0.555254\nY coordinate: 2.84\nX velocity: -1.29\nY velocity: 1.57\nAngle of the lander: 0.17\nAngular velocity of lander: -0.11249142698943615\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -6.88\nscore: Score: -353.13039424360693\n\nAction: \n
# 78     \n_\nObservation from last step: \nX coordinate: -0.568131\nY coordinate: 2.88\nX velocity: -1.29\nY velocity: 1.57\nAngle of the lander: 0.17\nAngular velocity of lander: -0.08713124319911003\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -3.68\nscore: Score: -356.8127258728542\n\nAction: \n
# 79    \n_\nObservation from last step: \nX coordinate: -0.581097\nY coordinate: 2.91\nX velocity: -1.30\nY velocity: 1.60\nAngle of the lander: 0.17\nAngular velocity of lander: -0.07510226219892502\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -6.72\nscore: Score: -363.53184381095195\n\nAction: \n
# 80     \n_\nObservation from last step: \nX coordinate: -0.594303\nY coordinate: 2.95\nX velocity: -1.32\nY velocity: 1.63\nAngle of the lander: 0.17\nAngular velocity of lander: -0.09333576075732708\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -8.24\nscore: Score: -371.7753006313322\n\nAction: \n
# 81    \n_\nObservation from last step: \nX coordinate: -0.607676\nY coordinate: 2.99\nX velocity: -1.34\nY velocity: 1.67\nAngle of the lander: 0.17\nAngular velocity of lander: -0.09689615108072758\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -7.67\nscore: Score: -379.44214491676166\n\nAction: \n
# 82    \n_\nObservation from last step: \nX coordinate: -0.621084\nY coordinate: 3.02\nX velocity: -1.34\nY velocity: 1.70\nAngle of the lander: 0.16\nAngular velocity of lander: -0.07092597428709269\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -7.03\nscore: Score: -386.46953616158413\n\nAction: \n
# 83    \n_\nObservation from last step: \nX coordinate: -0.634748\nY coordinate: 3.06\nX velocity: -1.36\nY velocity: 1.74\nAngle of the lander: 0.16\nAngular velocity of lander: -0.09126914665102959\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -8.96\nscore: Score: -395.42477756686276\n\nAction: \n
# 84    \n_\nObservation from last step: \nX coordinate: -0.648346\nY coordinate: 3.10\nX velocity: -1.36\nY velocity: 1.75\nAngle of the lander: 0.16\nAngular velocity of lander: -0.05392453633248806\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -5.03\nscore: Score: -400.45849703936057\n\nAction: \n
# 85    \n_\nObservation from last step: \nX coordinate: -0.661920\nY coordinate: 3.14\nX velocity: -1.36\nY velocity: 1.77\nAngle of the lander: 0.16\nAngular velocity of lander: -0.023792863357812166\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -5.72\nscore: Score: -406.1735682629145\n\nAction: \n
# 86    \n_\nObservation from last step: \nX coordinate: -0.675771\nY coordinate: 3.18\nX velocity: -1.38\nY velocity: 1.80\nAngle of the lander: 0.16\nAngular velocity of lander: -0.05687907803803682\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -8.30\nscore: Score: -414.46999774451484\n\nAction: \n
# 87    \n_\nObservation from last step: \nX coordinate: -0.689742\nY coordinate: 3.22\nX velocity: -1.40\nY velocity: 1.80\nAngle of the lander: 0.16\nAngular velocity of lander: -0.07112499326467514\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -4.93\nscore: Score: -419.40107386077966\n\nAction: \n
# 88    \n_\nObservation from last step: \nX coordinate: -0.703632\nY coordinate: 3.26\nX velocity: -1.39\nY velocity: 1.81\nAngle of the lander: 0.16\nAngular velocity of lander: -0.030940831638872623\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -5.05\nscore: Score: -424.4555990413057\n\nAction: \n
# 89     \n_\nObservation from last step: \nX coordinate: -0.717679\nY coordinate: 3.31\nX velocity: -1.40\nY velocity: 1.82\nAngle of the lander: 0.16\nAngular velocity of lander: -0.04837547894567251\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -6.07\nscore: Score: -430.5220481985374\n\nAction: \n
# 90    \n_\nObservation from last step: \nX coordinate: -0.731782\nY coordinate: 3.35\nX velocity: -1.41\nY velocity: 1.81\nAngle of the lander: 0.16\nAngular velocity of lander: -0.04802442155778408\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -4.60\nscore: Score: -435.12394358617445\n\nAction: \n
# 91    \n_\nObservation from last step: \nX coordinate: -0.746001\nY coordinate: 3.39\nX velocity: -1.42\nY velocity: 1.82\nAngle of the lander: 0.15\nAngular velocity of lander: -0.057178582064807415\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -5.67\nscore: Score: -440.7944845171261\n\nAction: \n
# 92     \n_\nObservation from last step: \nX coordinate: -0.760405\nY coordinate: 3.43\nX velocity: -1.44\nY velocity: 1.86\nAngle of the lander: 0.15\nAngular velocity of lander: -0.06530893035233021\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -8.67\nscore: Score: -449.4635332874904\n\nAction: \n
# 93   \n_\nObservation from last step: \nX coordinate: -0.774878\nY coordinate: 3.47\nX velocity: -1.45\nY velocity: 1.87\nAngle of the lander: 0.15\nAngular velocity of lander: -0.062416899017989635\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -5.71\nscore: Score: -455.16972492965624\n\nAction: \n
# 94    \n_\nObservation from last step: \nX coordinate: -0.789532\nY coordinate: 3.51\nX velocity: -1.46\nY velocity: 1.86\nAngle of the lander: 0.15\nAngular velocity of lander: -0.09130246937274933\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -5.38\nscore: Score: -460.55157249762436\n\nAction: \n
# 95     \n_\nObservation from last step: \nX coordinate: -0.804343\nY coordinate: 3.56\nX velocity: -1.48\nY velocity: 1.89\nAngle of the lander: 0.15\nAngular velocity of lander: -0.09808091446757317\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -7.86\nscore: Score: -468.4101414509166\n\nAction: \n
# 96    \n_\nObservation from last step: \nX coordinate: -0.819190\nY coordinate: 3.60\nX velocity: -1.48\nY velocity: 1.91\nAngle of the lander: 0.15\nAngular velocity of lander: -0.08377618156373501\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -6.31\nscore: Score: -474.72201231207185\n\nAction: \n
# 97    \n_\nObservation from last step: \nX coordinate: -0.834104\nY coordinate: 3.64\nX velocity: -1.49\nY velocity: 1.92\nAngle of the lander: 0.14\nAngular velocity of lander: -0.08307993412017822\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -5.43\nscore: Score: -480.15402462962595\n\nAction: \n
# 98     \n_\nObservation from last step: \nX coordinate: -0.849058\nY coordinate: 3.69\nX velocity: -1.49\nY velocity: 1.95\nAngle of the lander: 0.14\nAngular velocity of lander: -0.06252676248550415\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -7.71\nscore: Score: -487.8669582272706\n\nAction: \n
# 99   \n_\nObservation from last step: \nX coordinate: -0.863964\nY coordinate: 3.73\nX velocity: -1.49\nY velocity: 1.97\nAngle of the lander: 0.14\nAngular velocity of lander: -0.029002714436501265\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -6.13\nscore: Score: -493.99445793101347\n\nAction: \n
# 100  \n_\nObservation from last step: \nX coordinate: -0.879017\nY coordinate: 3.77\nX velocity: -1.50\nY velocity: 1.98\nAngle of the lander: 0.14\nAngular velocity of lander: -0.044564041309058666\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -6.55\nscore: Score: -500.53957429024916\n\nAction: \n
# 101    \n_\nObservation from last step: \nX coordinate: -0.894274\nY coordinate: 3.82\nX velocity: -1.52\nY velocity: 2.02\nAngle of the lander: 0.14\nAngular velocity of lander: -0.05987337324768305\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -9.18\nscore: Score: -509.7199283872271\n\nAction: \n
# 102    \n_\nObservation from last step: \nX coordinate: -0.909413\nY coordinate: 3.87\nX velocity: -1.51\nY velocity: 2.02\nAngle of the lander: 0.14\nAngular velocity of lander: -0.01903277589008212\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -4.48\nscore: Score: -514.1975150027624\n\nAction: \n
# 103    \n_\nObservation from last step: \nX coordinate: -0.924566\nY coordinate: 3.91\nX velocity: -1.52\nY velocity: 2.05\nAngle of the lander: 0.14\nAngular velocity of lander: 0.004758636350743473\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -7.55\nscore: Score: -521.7520731640409\n\nAction: \n
# 104    \n_\nObservation from last step: \nX coordinate: -0.939874\nY coordinate: 3.96\nX velocity: -1.53\nY velocity: 2.05\nAngle of the lander: 0.14\nAngular velocity of lander: -0.01442602719180286\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -6.65\nscore: Score: -528.4065967691613\n\nAction: \n
# 105   \n_\nObservation from last step: \nX coordinate: -0.955286\nY coordinate: 4.00\nX velocity: -1.54\nY velocity: 2.07\nAngle of the lander: 0.14\nAngular velocity of lander: -0.016013936838135123\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -7.29\nscore: Score: -535.7013521021381\n\nAction: \n
# 106    \n_\nObservation from last step: \nX coordinate: -0.970986\nY coordinate: 4.05\nX velocity: -1.57\nY velocity: 2.10\nAngle of the lander: 0.14\nAngular velocity of lander: -0.05561973433941603\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -9.06\nscore: Score: -544.7650003407924\n\nAction: \n
# 107    \n_\nObservation from last step: \nX coordinate: -0.986795\nY coordinate: 4.10\nX velocity: -1.58\nY velocity: 2.11\nAngle of the lander: 0.14\nAngular velocity of lander: -0.06298148073256016\nLeg 1 contact with ground flag: 0.0\nLeg 2 contact with ground flag: 0.0\nThe reward from the last step was: -6.65\nscore: Score: -551.4150402068778\n\nAction: \n
